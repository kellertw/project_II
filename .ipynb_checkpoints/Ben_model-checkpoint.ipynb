# %%
import pandas as pd
import sys
import sqlite3
import numpy as np
# !pip install sklearn --upgrade
# !pip install joblib
# Out:
# Requirement already up-to-date: sklearn in c:\users\bocli\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\bocli\anaconda3\lib\site-packages (from sklearn) (0.21.3)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\bocli\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.13.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\bocli\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\bocli\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.16.5)
# Requirement already satisfied: joblib in c:\users\bocli\anaconda3\lib\site-packages (0.13.2)

# %%
#importing data 
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("data/Casino.sqlite")
c = con.cursor()

# %%
c.execute("SELECT * FROM casinoSW limit 5;")
results= c.fetchall()
print(results)
# for row in c.execute("SELECT * FROM casinoSW"):
#     print(row)
# Out:
# [(0, 2014, 'Arizona', 'Coconino County', ' Tribal Authorized Casino', 'Alters or Cancels Transaction to Avoid CTR Requirement', 1, 35.829692, -111.773728), (1, 2014, 'Arizona', 'Coconino County', ' Tribal Authorized Casino', 'Exchanges Small Bills for Large Bills or Vice Versa', 1, 35.829692, -111.773728), (2, 2014, 'Arizona', 'Coconino County', ' Tribal Authorized Casino', 'Other Structuring', 1, 35.829692, -111.773728), (3, 2014, 'Arizona', 'Coconino County', ' Tribal Authorized Casino', 'Provided Questionable or False Documentation', 1, 35.829692, -111.773728), (4, 2016, 'Arizona', 'Coconino County', ' Tribal Authorized Casino', 'Account Takeover', 1, 35.829692, -111.773728)]

# %%
#column names
names = [description[0] for description in c.description]
names
# Out:
# ['id',
#  'Year',
#  'State',
#  'Countym',
#  'Industry',
#  'Suspicious Activity',
#  'Count',
#  'Lat',
#  'Long']

# %%
# def converter(x):
#     if x==' Tribal Authorized Casino':
#         return 0
#     elif x==' Card Club':
#         return 1
#     elif x==' State Licensed Casino':
#         return 2
#     else:
#         return 3
df = pd.read_sql_query("SELECT * FROM casinoSW",  con)
df
# Out:
#         id  Year    State          Countym                   Industry  \
# 0        0  2014  Arizona  Coconino County   Tribal Authorized Casino
# 1        1  2014  Arizona  Coconino County   Tribal Authorized Casino
# 2        2  2014  Arizona  Coconino County   Tribal Authorized Casino
# 3        3  2014  Arizona  Coconino County   Tribal Authorized Casino
# 4        4  2016  Arizona  Coconino County   Tribal Authorized Casino
# ...    ...   ...      ...              ...                        ...
# 7227  7227  2019     Utah    Summit County   Tribal Authorized Casino
# 7228  7228  2019     Utah    Summit County   Tribal Authorized Casino
# 7229  7229  2019     Utah    Summit County   Tribal Authorized Casino
# 7230  7230  2019     Utah    Summit County   Tribal Authorized Casino
# 7231  7231  2019     Utah    Summit County   Tribal Authorized Casino
#
#                                     Suspicious Activity Count        Lat  \
# 0     Alters or Cancels Transaction to Avoid CTR Req...     1  35.829692
# 1     Exchanges Small Bills for Large Bills or Vice ...     1  35.829692
# 2                                     Other Structuring     1  35.829692
# 3          Provided Questionable or False Documentation     1  35.829692
# 4                                      Account Takeover     1  35.829692
# ...                                                 ...   ...        ...
# 7227   Suspicious use of multiple transaction locations     1  40.872060
# 7228         Transaction Out of Pattern for Customer(s)     1  40.872060
# 7229   Transaction(s) Below BSA Recordkeeping Threshold     3  40.872060
# 7230                 Transaction(s) Below CTR Threshold     1  40.872060
# 7231           Two or More Individuals Working Together     2  40.872060
#
#             Long
# 0    -111.773728
# 1    -111.773728
# 2    -111.773728
# 3    -111.773728
# 4    -111.773728
# ...          ...
# 7227 -110.968486
# 7228 -110.968486
# 7229 -110.968486
# 7230 -110.968486
# 7231 -110.968486
#
# [7232 rows x 9 columns]

# %%
test_df = pd.read_sql_query("SELECT * FROM casinoSW",  con).dropna()
test_df
# Out:
#         id  Year    State          Countym                   Industry  \
# 0        0  2014  Arizona  Coconino County   Tribal Authorized Casino
# 1        1  2014  Arizona  Coconino County   Tribal Authorized Casino
# 2        2  2014  Arizona  Coconino County   Tribal Authorized Casino
# 3        3  2014  Arizona  Coconino County   Tribal Authorized Casino
# 4        4  2016  Arizona  Coconino County   Tribal Authorized Casino
# ...    ...   ...      ...              ...                        ...
# 7227  7227  2019     Utah    Summit County   Tribal Authorized Casino
# 7228  7228  2019     Utah    Summit County   Tribal Authorized Casino
# 7229  7229  2019     Utah    Summit County   Tribal Authorized Casino
# 7230  7230  2019     Utah    Summit County   Tribal Authorized Casino
# 7231  7231  2019     Utah    Summit County   Tribal Authorized Casino
#
#                                     Suspicious Activity Count        Lat  \
# 0     Alters or Cancels Transaction to Avoid CTR Req...     1  35.829692
# 1     Exchanges Small Bills for Large Bills or Vice ...     1  35.829692
# 2                                     Other Structuring     1  35.829692
# 3          Provided Questionable or False Documentation     1  35.829692
# 4                                      Account Takeover     1  35.829692
# ...                                                 ...   ...        ...
# 7227   Suspicious use of multiple transaction locations     1  40.872060
# 7228         Transaction Out of Pattern for Customer(s)     1  40.872060
# 7229   Transaction(s) Below BSA Recordkeeping Threshold     3  40.872060
# 7230                 Transaction(s) Below CTR Threshold     1  40.872060
# 7231           Two or More Individuals Working Together     2  40.872060
#
#             Long
# 0    -111.773728
# 1    -111.773728
# 2    -111.773728
# 3    -111.773728
# 4    -111.773728
# ...          ...
# 7227 -110.968486
# 7228 -110.968486
# 7229 -110.968486
# 7230 -110.968486
# 7231 -110.968486
#
# [7231 rows x 9 columns]

# %%
test_df["Industry"].value_counts()
# Out:
#  Tribal Authorized Casino    4478
#  State Licensed Casino       1520
#  Card Club                   1170
#  Other Casino/Card Club        63
# Name: Industry, dtype: int64

# %%
test_df["Countym"].value_counts()
# Out:
# San Diego County          424
# Clark County              404
# Los Angeles County        273
# Riverside County          264
# Contra Costa County       250
#                          ...
# Marin County                2
# Rio Blanco County           2
# San Luis Obispo County      2
# Sierra County               1
# Storey County               1
# Name: Countym, Length: 108, dtype: int64

# %%
cleanup_industry = {"Industry": {' Tribal Authorized Casino': 0, ' Card Club':1,
                                 ' State Licensed Casino': 2, ' Other Casino/Card Club': 3}}

# %%
test_df.replace(cleanup_industry, inplace=True)

# %%
test_df["Industry"].value_counts()
# Out:
# 0    4478
# 2    1520
# 1    1170
# 3      63
# Name: Industry, dtype: int64

# %%
test_df
# Out:
#         id  Year    State          Countym  Industry  \
# 0        0  2014  Arizona  Coconino County         0
# 1        1  2014  Arizona  Coconino County         0
# 2        2  2014  Arizona  Coconino County         0
# 3        3  2014  Arizona  Coconino County         0
# 4        4  2016  Arizona  Coconino County         0
# ...    ...   ...      ...              ...       ...
# 7227  7227  2019     Utah    Summit County         0
# 7228  7228  2019     Utah    Summit County         0
# 7229  7229  2019     Utah    Summit County         0
# 7230  7230  2019     Utah    Summit County         0
# 7231  7231  2019     Utah    Summit County         0
#
#                                     Suspicious Activity Count        Lat  \
# 0     Alters or Cancels Transaction to Avoid CTR Req...     1  35.829692
# 1     Exchanges Small Bills for Large Bills or Vice ...     1  35.829692
# 2                                     Other Structuring     1  35.829692
# 3          Provided Questionable or False Documentation     1  35.829692
# 4                                      Account Takeover     1  35.829692
# ...                                                 ...   ...        ...
# 7227   Suspicious use of multiple transaction locations     1  40.872060
# 7228         Transaction Out of Pattern for Customer(s)     1  40.872060
# 7229   Transaction(s) Below BSA Recordkeeping Threshold     3  40.872060
# 7230                 Transaction(s) Below CTR Threshold     1  40.872060
# 7231           Two or More Individuals Working Together     2  40.872060
#
#             Long
# 0    -111.773728
# 1    -111.773728
# 2    -111.773728
# 3    -111.773728
# 4    -111.773728
# ...          ...
# 7227 -110.968486
# 7228 -110.968486
# 7229 -110.968486
# 7230 -110.968486
# 7231 -110.968486
#
# [7231 rows x 9 columns]

# %%
new_test_df = test_df.drop(columns=["Countym", "State", "Suspicious Activity", "id", "Lat", "Long"])

new_test_df["Count"] = pd.to_numeric(df["Count"], errors='coerce').fillna(0)

new_test_df
# Out:
#       Year  Industry  Count
# 0     2014         0    1.0
# 1     2014         0    1.0
# 2     2014         0    1.0
# 3     2014         0    1.0
# 4     2016         0    1.0
# ...    ...       ...    ...
# 7227  2019         0    1.0
# 7228  2019         0    1.0
# 7229  2019         0    3.0
# 7230  2019         0    1.0
# 7231  2019         0    2.0
#
# [7231 rows x 3 columns]

# %%
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import MinMaxScaler,StandardScaler, Normalizer
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.feature_selection import SelectKBest,f_classif
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.metrics import classification_report as report
from random import randint
from sys import maxsize
import warnings
from sklearn.exceptions import DataConversionWarning,UndefinedMetricWarning
warnings.filterwarnings(action='ignore',category=DataConversionWarning)
warnings.filterwarnings(action='ignore',category=UndefinedMetricWarning)

#pipeline: 1) scales model 2) reduces dimensionality 3) tests the model

#this function takes an arugent n_features representing the total number of features to keep
#by iterating through n_features=1 to n_features = max_features we will determine the best set of features
"""
    SUMMARY:  Creates a pipeline with the given data preprocessors and model and then tests the model using the pipeline
    
    
    
    IN: n_features = denotes the number of features, n_features, to select from the overall data set
                        there is a total of 40 columns in the input data and we may not want all of that data
                        some of the featuress could be 'noise' and not be useful to predicting the output.
                        We will use Principal Component Analysis, by way of the SelectKBest function and the f_classif function
                        do decide which selection of features is optimal
        
        testmodel = denotes the model we wish to test in this test run.  could be any classification model that supports
                        the functions "fit" and "fit_transform"
                        

            
    OUT:  Returns the overall model precision

"""

def RunTest(n_features,testmodel):
    X= new_test_df.drop(columns=["Industry"],inplace=False)
    y= new_test_df["Industry"].values.reshape(-1,1) # same as  y = [ df["koi_disposition"].values ]
    X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=randint(0,2**32 - 1))
    #testscaler=MinMaxScaler(feature_range=(-1,1),copy=True)
    testscaler=StandardScaler()
    normalizer=Normalizer()
    testpca=SelectKBest(f_classif,k="all")
    mypipeline=Pipeline([('featurescale',testscaler),("mynormalizer",normalizer), ("anova",testpca), ("model",testmodel)])    
    mypipeline.fit(X_train,y_train)
    predictions=mypipeline.predict(X_test)
    return report(y_test,predictions,output_dict=True)
    



precisions={}
models={KNN(n_neighbors=1):"knn",RandomForestClassifier():"rff",SVC():"svc", LogisticRegression():"lin",
       } #chooses all models from dict list beforehand
for model,name in models.items():
    for n_features in range(3,1,-1): #loops through each model and every step of the way it throws out the worst column
        score=RunTest(n_features,model)["weighted avg"]['precision']
        n=n_features
        precisions[float(score)]=(name,n)
answer=max(precisions)
print(answer,str(precisions.get(answer)))
# Out:
# C:\Users\bocli\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\bocli\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\bocli\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.5255496672840776 ('svc', 3)
# C:\Users\bocli\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\bocli\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\bocli\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\bocli\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
# TODO: Sort Top 5 Suspicious Activity, Create new DataFrame, Run regression or cluster model and look to next unique county
act_state = df
act_state.head()
# Out:
#    id  Year    State          Countym                   Industry  \
# 0   0  2014  Arizona  Coconino County   Tribal Authorized Casino
# 1   1  2014  Arizona  Coconino County   Tribal Authorized Casino
# 2   2  2014  Arizona  Coconino County   Tribal Authorized Casino
# 3   3  2014  Arizona  Coconino County   Tribal Authorized Casino
# 4   4  2016  Arizona  Coconino County   Tribal Authorized Casino
#
#                                  Suspicious Activity Count        Lat  \
# 0  Alters or Cancels Transaction to Avoid CTR Req...     1  35.829692
# 1  Exchanges Small Bills for Large Bills or Vice ...     1  35.829692
# 2                                  Other Structuring     1  35.829692
# 3       Provided Questionable or False Documentation     1  35.829692
# 4                                   Account Takeover     1  35.829692
#
#          Long
# 0 -111.773728
# 1 -111.773728
# 2 -111.773728
# 3 -111.773728
# 4 -111.773728

# %%
# Replacing Count column's strings and "," with int dtypes
act_state["Count"]=pd.Series(act_state["Count"].astype(str))
act_state["Count"] = act_state["Count"].apply(lambda x: float(x.split()[0].replace(',', '')))
act_state["Count"].astype(int)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7227    1
# 7228    1
# 7229    3
# 7230    1
# 7231    2
# Name: Count, Length: 7232, dtype: int32

# %%
new_act_state = act_state.sort_values(["Count"], ascending=False).dropna()
new_act_state.head()
# Out:
#         id  Year   State       Countym                Industry  \
# 5335  5335  2016  Nevada  Clark County   State Licensed Casino
# 5399  5399  2017  Nevada  Clark County   State Licensed Casino
# 5463  5463  2018  Nevada  Clark County   State Licensed Casino
# 5269  5269  2015  Nevada  Clark County   State Licensed Casino
# 5352  5352  2016  Nevada  Clark County   State Licensed Casino
#
#                            Suspicious Activity   Count        Lat        Long
# 5335    Minimal Gaming with Large Transactions  3123.0  36.214257 -115.013812
# 5399    Minimal Gaming with Large Transactions  2977.0  36.214257 -115.013812
# 5463                             Other Casinos  2776.0  36.214257 -115.013812
# 5269    Minimal Gaming with Large Transactions  2540.0  36.214257 -115.013812
# 5352  Suspicion Concerning the Source of Funds  2536.0  36.214257 -115.013812

# %%
new_act_state.groupby(["Count","State"]).size().reset_index().head(5)
# Out:
#    Count       State     0
# 0    1.0     Arizona   285
# 1    1.0  California  1527
# 2    1.0    Colorado   158
# 3    1.0      Nevada   266
# 4    1.0  New Mexico   264

# %%
new_act_state["Count"].sort_values
# Out:
# <bound method Series.sort_values of 5335    3123.0
# 5399    2977.0
# 5463    2776.0
# 5269    2540.0
# 5352    2536.0
#          ...
# 3740       1.0
# 3741       1.0
# 3749       1.0
# 3750       1.0
# 3616       1.0
# Name: Count, Length: 7231, dtype: float64>

# %%
# Focus on models only on Las Vegas
# Focus on models only on Casinos
las_vegas_df = df.head().dropna()
las_vegas_df
# Out:
#    id  Year    State          Countym                   Industry  \
# 0   0  2014  Arizona  Coconino County   Tribal Authorized Casino
# 1   1  2014  Arizona  Coconino County   Tribal Authorized Casino
# 2   2  2014  Arizona  Coconino County   Tribal Authorized Casino
# 3   3  2014  Arizona  Coconino County   Tribal Authorized Casino
# 4   4  2016  Arizona  Coconino County   Tribal Authorized Casino
#
#                                  Suspicious Activity  Count        Lat  \
# 0  Alters or Cancels Transaction to Avoid CTR Req...    1.0  35.829692
# 1  Exchanges Small Bills for Large Bills or Vice ...    1.0  35.829692
# 2                                  Other Structuring    1.0  35.829692
# 3       Provided Questionable or False Documentation    1.0  35.829692
# 4                                   Account Takeover    1.0  35.829692
#
#          Long
# 0 -111.773728
# 1 -111.773728
# 2 -111.773728
# 3 -111.773728
# 4 -111.773728

# %%
las_vegas_df = las_vegas_df
